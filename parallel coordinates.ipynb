# %% [markdown]
# # Parallel Coordinates
#
# ---

# %% [markdown]
# ## Dealing with multivariate data
#
# - Dimensionality reduction
# - Small multiples
# - Novel glyph types
# - **Parallel Coordinates**
# - Interaction (with any of the above)

# %% [markdown]
# ### parallel Coordinates (Inselberg)
#
# - 3 different piece of data with 5 variables
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Construction
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Running Example
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Design Choices/Constraints
#
# - Different variables with different ranges
#     - Normalization (e.g., 0-1)
#     - Ordering (topto bottom, bottom to top)
#     - Ordering of axes
# - Extensions
#     - Categorical data
#     - Independent axes

# %% [markdown]
# ### Free Options
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Takeaways
#
# - Parallet coordinates are powerful
# - Have their own set of limitations
#     - Learning to use
#     - Dimensions needs to make sense as parallel
# - Questions to answer
#     - How to set axes, how to order them, etc.
# - Various "derivative" forms exist
