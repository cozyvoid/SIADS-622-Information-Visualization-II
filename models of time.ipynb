# %% [markdown]
# # Models of Time
#
# ---

# %% [markdown]
# ## Some notes on temporal data...

# %% [markdown]
# ### Data Sets  (generally)
#
# - Tuples
#     $D = {(t_1, d_1), (t_2, d_2),...(t_n, d_n)}$
# - Events - frequent motivator, specific points in time when something "interesting" happens
# - Ordering - A before B
# - But...

# %% [markdown]
# ### Temporal Data - dichotomies
#
# ![image.png](attachment:image.png)
#
# - Discrete time vs interval time
# - Linear time vs cyclic time
# - Ordinal time vs continuous time
# - Ordered time vs branching time
#     - Single branch with one ordering vs many possibilites

# %% [markdown]
# ### Branching Time
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Takeaways
#
# - Static vs Dynamic
#     - "Whole story" view or as-it-happens view
# - Data vs Event
#     - Data is of intereset, or only key events
# - Conventional vs Multivariate
#     - Time as dominant with a small number of extra variables, or
#     - Time as part of a big set
