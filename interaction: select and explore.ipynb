# %% [markdown]
# # Interaction: Select and Explore
#
# ---

# %% [markdown]
# ### 7 Categories
#
# - `Select`
# - Explore
# - Reconfigure
# - Encode
# - Abstract/Elaborate
# - Connect
# - Filter

# %% [markdown]
# ### Selection: How do we choose it?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Select
#
# ![image-2.png](attachment:image-2.png)
#
# - Mark something as interesting
#     - Mark items to keep track of them
#     - Often precedes other operations
# - Example:
#     - Selecting a placemark in Google Maps
#
#     ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Selection: Pop-up tooltips
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Selection: How do we choose it?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Label everything!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Selection: Label?
#
# - How do we know what to select?
# - Label should be:
#     - Readable
#     - Non-ambiguous
#     - Not occlude (hide or obscure from prominence or view) pertinent information

# %% [markdown]
# ### Cetainly don't want this...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Labeling/Selection techniques
#
# ![image.png](attachment:image.png)
#
# - Static techniques
# - Cartography
# - Algorithmic
#     - Rule-based optimization, etc.

# %% [markdown]
# ### Selection: Excentric Labeling (example)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Explore
#
# - Show things not in view
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Takeaways
#
# - Select - necessary when there's a lot of data
#     - Direct manipulation: mouse over, click, circle, etc.
#     - Consider the labels
# - Explore
#     - When there's data of view (same "hierarchical level")
#     - "Pan" or "walk" through space
