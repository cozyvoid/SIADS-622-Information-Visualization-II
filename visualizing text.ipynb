# %% [markdown]
# # Visualizing Text
#
# ---

# %% [markdown]
# ### Text
#
# - Documents
#     - Articles, books, novels
#     - Computer programs
#     - Email, Web pages, blogs
#     - Tags, comments
#
# - Collections of documents
#     - Messages (e-mail, etc.)
#     - Social nets (profiles)
#     - Academic collaborations (publications)

# %% [markdown]
# ### Text Vis
#
# - Tasks
#     - Common themes in different neew articles
#     - Relationships mined from legal texts
#     - Social media communication flows
#     - DNS text visualization
#     - Visualization of search results
#     - etc.

# %% [markdown]
# ### Treatment of Text
#
# - Nominal?
# - High dimensional (many words)
# - Orderable
# - Meanings and relations
#     - Correlations (cities)
#     - Order (months)
#     - Membership (sports)
#     - Hierarchies, antonyms, synonyms, entities, etc.

# %%
encoding(text) = ?

# %% [markdown]
# ### Impact of Weighting
#
# - Frequency is one way
# - Not always appropriate
#     - Stop words
#     - Expectation of seeing certain things
# - Weighting schemes developed
#     - TF-IDF
#         - weight by number of times word appears in collection
#     - Probabilities
#         - weight by probability of seeing the word
#     - etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Keyword Weighting
#
# The *apple* does what the *apple* can do.
#
# - Term Frequency
#     - $tf_{td} = count(t)$ in d
#     - Log frequency to smooth: $log(1+tf_{td})$
#     - Normalize for proportion: $tf_{td} / \Sigma_t  tf_{td}$
#
# *The* apple does what *the* apple can do

# %% [markdown]
# - Term Frequency
#     $ tf_{td} = count(t)$ in $d$
#
# - TFIDF
#         $tf.idf = log(1+tf_{td})* log(N/df_t)
#     $df_t$ = #docus containing $t$; N = $ of docs
#
# The apple does what the apple can do
# The pears are pretty cool too

# %% [markdown]
# ### Frequency Stats
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# > Monroe, Colaresi, and Quinn
# >> Political Analysis, 16(4):372-403, 2009

# %% [markdown]
# ### Takeaways
#
# - Text encoding is unclear
# - Many ways to convert text to numbers
# - Things to worry about in deciding:
#     - Nature of the underlying task
#     - Nature of the underlying data
