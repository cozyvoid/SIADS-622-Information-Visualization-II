# %% [markdown]
# # Dimensionality Reduction
#
# ---

# %% [markdown]
# ### Dealing with multivariate data
#
# - Dimensionality reduction
# - Small multiples
# - Novel glyph types
# - Parallel Coordinates
# - Interaction (with any of the above)

# %% [markdown]
# ### The idea...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Reduction techniques
#
# - Finding "important" features:
#     - Multi-dimensional Scaling (MDS)
#     - Principle component analysis (PCA)
#     - Linear discriminant analysis (LDA)
#     - Factor analysis
#
#     - How we pick is a statistics problems
#         - Data distribution is one factor

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# - Basic idea: draw a line and project the data so that things that are far in 2D are far in 1D

# %% [markdown]
# ### Multi-dimensional Scaling
#
# - Optimization problems
# - Pair-wise similarity/dissimilarity of each piece of (multi-dimensional) data
# - Tries to plot the n-dimensional data on 2 or 3 dimensions
#     - Preserves similarity as well as possible in the reduced space
#
# - The idea (in practice)
#
# data x variables &rarr; data x data &rarr; 2D/3D
#
# ![image.png](attachment:image.png)
#
# - Similarity functions, e.g.,
#
# ```
# sim(fish1, fish2) =
#     overlapping genetic markers
#
# sim (car1, car2_ =
#     (doors1-doors2)^2 + (cylinders1-cylinders2)^2 + ...
# ```

# %% [markdown]
# ### Example
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Running Example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Challenges of dimensionality reduction
#
# - Dimensions of visualizations not directly related to original dimensions
#     - May be hard to interpret or explain
# - Different slices yeild potentially different views
#     - Some randomization may be involved

# %% [markdown]
# ### Takeaways
#
# - When you have too many dimensions...
#     - Find ways to reduce them
# - There are many techniques
# - All are optimizations (imperfect representations)
# - Your choice will control how you want distances to be preserved and what they mean
