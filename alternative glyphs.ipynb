# %% [markdown]
# # Alternative Glyphs
#
# ---

# %% [markdown]
# ### Dealing wih multivariate data
#
# - dimensionality reduction
# - small multiples
# - **novel glyph types**
# - parallel coordinates
# - interaction (with any of the above)

# %% [markdown]
# ## Start simple...

# %% [markdown]
# ### Chernoff Faces
#
# ![image.png](attachment:image.png)
#
# - Herman Chernoff (1973)
# - Different faces are easy for us to recognize/differentiate
# - Why not encode data in faces?
#
# - Decreasing order
#     - area of face
#     - shape of face
#     - length of nose
#     - location of mouth
#     - curve of smile
#     - width of mouth
#     - location, separation, angle, shape, and width of eyes
#     - location of pupil
#     - locaiton, angle, width of eyebrows

# %% [markdown]
# ### Running Example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Star Glyphs
#
# - Dimensions along circle
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Takeaways
#
# - We aren't stuck with standard chart types
# - There are alternative "glyphs" that can be used in small multiple configurations
# - But they all have a "cost"
#     - Learning how to use them
#     - Broken semantics
