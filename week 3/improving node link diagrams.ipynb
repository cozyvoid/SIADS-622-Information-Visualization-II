# %% [markdown]
# # Improving Node Link Diagrams
# ## (Reduction + Interaction)
#
# ---

# %% [markdown]
# ### Edge bundling
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Cluster nodes
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Can we do it through data interaction?

# %% [markdown]
# ### Vizter
#
# ![image.png](attachment:image.png)
#
# - Focus on social connection - specific nodes
# - Techniques (node-link) ensures that communities + ego-nets (individual focused  subnetwork) visible
# - Interactions further boost performance

# %% [markdown]
# ### Semantic Substrates
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# - Focus on overall patterns between "classes" of cases
# - Layout is not "organic"
#     - X-axis is time
#     - Y-axis is case type
# - Interactions further boost focus
#     - Filtering on key dimensions (time, case types, etc.)
# - Like parallel coordinates

# %% [markdown]
# ### Takeaways
#
# - Can further optimize by doing "data reduction"
#     - Merge edges and nodes as appropriate
# - Combinations of interaction + layout can also help

# %% [markdown]
# ### Summary
#
# - Hierarchical and network datasets are complex for visualization
# - Standard techniques largely work for smaller datasets
#     - Node-link, space-filling for hierachical
#     - Node-link, matrix, etc. for network
# - Really need to pick the right algorithms and interactions
