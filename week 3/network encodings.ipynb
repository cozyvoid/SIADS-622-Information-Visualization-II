# %% [markdown]
# # Network Encodings
#
# ---

# %% [markdown]
# ### Schneiderman's Criteria
#
# 1. Every node is visible
# 2. For every node you can count degree
# 3. For every link you can follow it from source to destination
# 4. Clusters and outliers are identifiable

# %% [markdown]
# ### Issues
#
# - How do we draw the nodes?
# - How do we draw the links?
# - How do we lay out the graph?

# %% [markdown]
# ### Vertex design
#
# ![image.png](attachment:image.png)
#
# - Shape
# - Color
# - Size
# - Location
# - Label

# %% [markdown]
# ### Link Design
#
# ![image.png](attachment:image.png)
#
# - Color
# - Size
# - Label
# - Shape
#     - Polyline
#     - Straight
#     - Orthogonal
#     - Grid
#     - Curved
#     - etc.

# %% [markdown]
# ## Can we do it through layout?

# %% [markdown]
# ### Layout Heuristics
#
# ![image.png](attachment:image.png)
#
# - Planar
#
# ![image-2.png](attachment:image-2.png)
#
# - Grid-based
#
# ![image-3.png](attachment:image-3.png)
#
# - Orthogonal
#
# ![image-4.png](attachment:image-4.png)
#
# - Curved lines
#
# ![image-5.png](attachment:image-5.png)
#
# - Hierarchies
#
# ![image-6.png](attachment:image-6.png)
#
# - Curved
#
# - ...

# %% [markdown]
# ### What makes a layout good?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Planar Graphs
#
# - Graphs that can be laid out without edge crossings
#
# ![image.png](attachment:image.png)
#
# - Which one is planar?

# %% [markdown]
# ### Non-planar graphs
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### What algorithms get us this?

# %% [markdown]
# ### Minimum Spanning Tree
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Sugiyama
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Force Directed
#
# - Treat edges like springs
#     - Pull towards
# - Treat nodes like charged particles
#     - Pull away
# - Repeatedly calculate in simulation
# - Different tensions/gravities will cause different behaviors

# %% [markdown]
# ## Some alternatives...

# %% [markdown]
# ### Attribute Driven Layouts - Skitter
#
# ![image.png](attachment:image.png)
#
# - Angle
#     - Longitude of node location
# - Radius
#     - Function of out-degree (more, closer in)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# > Matrix representation of Les Miserables character interctions

# %% [markdown]
# ### NodeTrix
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# > E Coli

# %% [markdown]
# ### Takeaways
#
# - Node-link are the primary vis type
#     - Many, many algorithms for layout and many choices of encodings
#     - SHould try different layouts to see what works for your data
# - Interaction can also boost effectiveness
# - Worth considering if there are better ways
#     - Matrices, hive plots
