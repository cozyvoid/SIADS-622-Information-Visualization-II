# %% [markdown]
# # Tea Leaves and Text
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
# > Kevin Boyack, Ketan Mane, Katy Borner 2004
# >> Mapping medline papers, genes, and proteins related to Melanoma research, IV2004 Conference

# %% [markdown]
# ![image.png](attachment:image.png)
#
# > Interpretation and Trust: Designing Model-Driven Visualizations for Text Analysis, Chuang et al.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://nlp.stanford.edu/projects/dissertations/browser.html
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Takeways
#
# - Text is "interpretable"
# - We tend to over-read and create narratives where none exist
# - Caution is warranted with visualization techniques for text

# %% [markdown]
# ### Summary
#
# - Text data is everywhere
# - Text encoding is complex
# - Lots of tasks &rarr; word, sentence, document, collection, search, etc.
# - Many options for representing text directly and trhough "proxy" encodings
# - Watch out for over-reading
