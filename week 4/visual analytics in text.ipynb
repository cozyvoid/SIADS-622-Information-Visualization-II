# %% [markdown]
# # Visual Analytics in Text
#
# ---

# %% [markdown]
# ### Social datasets
#
# - Dimensions
#     - Who (senders/receivers)
#     - What (content)
#     - When (temporal)
# - Cross-products are of interest

# %% [markdown]
# ### Visualizing Usenet
#
# - Viegas + Smith, HICSS'04
# - Understand and compare newsgroups and people
# - Visualize posts, thread lenght, time

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-3.png](attachment:image-3.png)
# > Jigsaw, Stasko, Gorg, & Lio, Information Visualization '08

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Jigsaw
#
# - Target sense-making scenario
# - Variety of visualizations at different levels
#     - Word to entity-document, entity-entity
# - Focus on entity-document, entity-entity
# - Search + interactive exploration

# %% [markdown]
# ### Takeaways
#
# - Relationships between entities (people, places, threads, companies, etc.) are important
# - Often a temporal component (relationships change)
# - Analyst tools apply to many domains
# - Isolate sub-tasks/questions
