# %% [markdown]
# # Other Kinds of Text
#
# ---

# %% [markdown]
# ### Other kind sof text
#
# - Code
#     - Software engineering community
# - Biological data
#     - Bioinformatics
# - ...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://artport.whitney.org/commissions/codedoc/Paley/CodeProfiles_800x600.htm
#
# ![image-2.png](attachment:image-2.png)
#
# http://pleuma.cc.gatech.edu/aristotle/Tools/tarantula/
#
# ![image-3.png](attachment:image-3.png)
# > Niu, Y., Otasek, D., Jurisica, I. Evaluation of linguistic features useful in extraction of interactions from PubMed,; Application to annotating known, high-throughput and predicted interactions in I2D. Bioinformatics, 2009

# %% [markdown]
# ### Takeaways
#
# - We like to represent manny kinds of things as text
# - Think about your data
#     - Does it make sense to view it as text?
#     - What of the many vis techniques apply now?
