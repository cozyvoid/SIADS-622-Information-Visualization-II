# %% [markdown]
# # Showing all the Data
#
# ---

# %% [markdown]
# ## So we can't reduce the data, what can we do?

# %% [markdown]
# ### Dealing with multivariate data
#
# - Dimensionality reduction
# - **Small multiples**
# - Novel glyph types
# - Parallel Coordinates
# - Interaction (with any of the above)

# %% [markdown]
# ### Small Multiples I
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# But... small can mean really small (details hard to pick out)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Easy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Not Easy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - To ask:
#     - Is the target pattern obvious?
#     - Is there a trend in the data?

# %% [markdown]
# ### Running Example
#
# ![image.png](attachment:image.png)
#
# - Nice features:
#     - All comparisons
#     - Can identify "outliers" or patterns of interest

# %% [markdown]
# ### Scatter plot matrix (SPLOM)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Takeaways
#
# - The more dimensions the less "single chart" options we have (limit of retinal variables)
# - Small multiples
#     - support comparisons within each plot very well
#     - support comparison between plots (but not as well)
#     - can be used to identify "outliers" or intersting patterns
