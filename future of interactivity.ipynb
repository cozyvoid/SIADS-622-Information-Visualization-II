# %% [markdown]
# # The Future of Interactivity
#
# ---

# %% [markdown]
# ## New ways of interacting
# #### (not just mouse)

# %% [markdown]
# ### Dust and Magnets 2.0
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Smartcues
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Takeaways
#
# - Various technologies are driving novel interaction techniques
#     - Touch
#     - Speech
#     - VR/AR
# - Don't use them because they're "cool", use them because theyy add something

# %% [markdown]
# ### Summary:
#
# - Interaction key for lots of infovis applications
# - Static representations don't scale, aren't easy to explore, etc.
# - Multiple views amplofy importance of interactivity
# - Interaction facilitates dialog between user and visualization system
