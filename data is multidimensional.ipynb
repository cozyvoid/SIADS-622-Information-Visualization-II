# %% [markdown]
# # Data is Multidimensional
#
# ---

# %% [markdown]
# ### A simple example...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Remember the Mackinlay APT algorithm?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ranking of Perceptial Tasks
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### A less simple example...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ranking of Perceptual Tasks
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### We'll cover some strategies
#
# - Dimensionality reduction
# - Small multiples
# - Novel glyph types
# - Parallel Coordinates
# - Interaction (with any of the above)

# %% [markdown]
# ### Takeaways
#
# - Multidimensional data is ubiquitous
# - Complex multidimensional data doesn't lend itself to simple chart types
# - Strategies:
#     - Reduction, small multiples, new encodings, and interaction
