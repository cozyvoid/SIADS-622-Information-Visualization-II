# %% [markdown]
# # Better Hierarchies Through Space Filling
#
# ---

# %% [markdown]
# ### Example
#
# - Total sales ($2000)
# 	- Fruit ($600)
# 		- Apples ($100)
# 		- Cherries ($100)
# 		- Strawberries ($100)
# 		- Grapes ($200)
# 	- Meat ($800)
# 		- Chicken ($400)
# 		- Beef ($200)
# 		- Pork ($200)
# 	- Dairy ($600)
# 		- Milk ($300)
# 		- Cheese ($300)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example
# ### color for double-encoding
#
# - Total sales ($2000)
# 	- Fruit ($600)
# 		- Apples ($100)
# 		- Cherries ($100)
# 		- Strawberries ($100)
# 		- Grapes ($200)
# 	- Meat ($800)
# 		- Chicken ($400)
# 		- Beef ($200)
# 		- Pork ($200)
# 	- Dairy ($600)
# 		- Milk ($300)
# 		- Cheese ($300)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example
# ### color for extra variable
#
# - Total sales ($2000)
# 	- Fruit ($600)
# 		- Apples ($100, 10)
# 		- Cherries ($100, 10)
# 		- Strawberries ($100, 100)
# 		- Grapes ($200, 10)
# 	- Meat ($800)
# 		- Chicken ($400, 20)
# 		- Beef ($200, 20)
# 		- Pork ($200, 60)
# 	- Dairy ($600)
# 		- Milk ($300, 40)
# 		- Cheese ($300, 60)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The problem with treemaps...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Internet News Groups
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Variation: Cushion Treemap
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### FundExplorer
#
# ![image.png](attachment:image.png)
# > Csallner et al, 2003

# %% [markdown]
# ### Other Space Filling Systems
#
# ![image.png](attachment:image.png)
# > http://www.cs.umd.edu/hcil/tree-map-history/

# %% [markdown]
# ### Takeaways
#
# - Space filling are a great alternative to node-link
# 	- More effective use of space
# - Laying them out is an optimization problem
# - Wherever there are optimization problems there are tones of solutions...
# - As always, data and task will constrain your choices

# %% [markdown]
# ![image.png](attachment:image.png)
# > https://treevis.net/
