# %% [markdown]
# # Connect and Filter
#
# ---

# %% [markdown]
# ### 7 Categories
#
# - Select
# - Explore
# - Reconfigure
# - Encode
# - Abstract/Elaborate
# - `Connect`
# - Filter

# %% [markdown]
# ## Connect
# ### Show associations and relationships

# %% [markdown]
# ### Connect: Brushing
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Connect: Related Objects
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Filter: NameVoyager
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Filter: Faceted Browsing
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Filter: HomeFinder
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Filter: Dynamic Query
#
# - Popular + useful

# %%
SELECT house_address
FROM listing
WHERE prices >= 200000 AND 
              price <= 400000 AND 
              bathrooms >= 3 AND 
              garage == 2 AND 
              bedrooms >= 4

# %% [markdown]
# ### Filter: +/-'s of DQ
#
# ![image.png](attachment:image.png)
#
# - Positives:
#     - Don't have to learnm SQL or schema
#     - Dynamic and interactive
#     - Great for seeing tradeoffs
# - Some issues:
#     - Conjunctions only (ands)
#     - No fuzzy matches
#     - No anticipation of data in/out of class

# %% [markdown]
# ### Filter: Data in controls
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Filter: More like this (Generalized Selection)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Takeaways
#
# - Connect
#     - Bridges visualizations or data
# - Filter
#     - Allows for focus
# - Important 1: distinguish reason for interaction (the type) from the technique (mouse-over, click, drag, etc.)
# - Important 2: most effective approaches combine interaction types/techniques
