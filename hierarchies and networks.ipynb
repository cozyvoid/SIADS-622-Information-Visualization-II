# %% [markdown]
# # Hierarchies and Networks
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# > The Royal Progenei of our most sacred King James, 1603

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hierarchical Data
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Takeaways
#
# - Hierarchical and network structures are very common
# - Many types of data can be mapped to these structures
#     - Everything from genes to text
# - Visualizing them sothey make sense will be a hard problem
#     - We want to avoid "spaghetti" plots
