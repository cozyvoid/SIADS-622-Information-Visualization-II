# %% [markdown]
# # Hierarchies
#
# ---

# %% [markdown]
# ### League of Nations
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Department of Molecular, Cellular, and Developmental Biology
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Sunburst Diagram, D3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hierarchical data
#
# - Genealogies (family histories)
# - Animal kingdom
# - Organization chart
# - File Organizations
# - Object oriented information
# - Others?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Node-Link
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Node-Link (alternative)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hierarchical Vis
#
# - Tasks
# 	- How much depth? How much fanning?
# 	- How far are two nodes?
# 	- How many subclasses?
# 	- How far down the hierarchy?
# 	- Which subtree contains entity?
# 	- Which subtree contains matches?
# 	- Which subtree contains more matching items than others?
# 	- etc.
#
# - Techniques
# 	- Trees + SpaceFillings
# - Algorithms
# 	- Render nice images
# 	- Scale
# 		- Deal with excessive fan/depth issues

# %% [markdown]
# ### Tree Visualization
#
# - Depth first?
#
# ![image.png](attachment:image.png)
#
# - Bottom up?
#
# ![image-2.png](attachment:image-2.png)
#
# - Constraints/problems with rendering?
# 	- Branching factor
# 	- Single branch depth
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Takeaways
#
# - Hierarchical data structures are "trees" and "DAGs"
# 	- No cycles
# - Common vis approaches: node-link and space filling
# - Extremes (too wide or too deep) will force use to be clever in design/choice
